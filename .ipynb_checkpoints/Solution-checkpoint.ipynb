# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler
from statsmodels.regression.linear_model import WLS
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.stattools import durbin_watson
import statsmodels.stats.diagnostic as smsdia
from sklearn.metrics import r2_score
RND_STATE = 344
# %matplotlib inline

# %% [markdown]
# ## 1. Загрузка данных

# %%
data = pd.read_csv('data/hotel_data.csv', sep=';')

# %%
data.head()
# Out:
#                       Hotel name  Rating  Stars  Distance to the sea  \
# 0                  Bonanova Park     7.7    2.0                  7.0
# 1  Travelodge Barcelona Poblenou     7.9    1.0                  0.5
# 2   Senator Barcelona Spa Hotel      7.8    4.0                  5.0
# 3                  Hotel Medicis     7.9    2.0                  2.0
# 4                     Paral-lel      8.4    2.0                  0.5
#
#    Distance to the downtown  Room area  Swimming pool  Price
# 0                       5.0       16.0              0     63
# 1                       2.0       15.0              0     83
# 2                       3.0       21.0              1     91
# 3                       1.0       10.0              0     87
# 4                       1.0       19.0              0    102

# %% [markdown]
# ### 1.1 Описание данных

# %%
data.describe()
# Out:
#            Rating       Stars  Distance to the sea  Distance to the downtown  \
# count  208.000000  207.000000           208.000000                208.000000
# mean     7.980288    3.260870             2.585096                  1.258173
# std      0.491125    0.841615             1.656875                  1.168520
# min      6.400000    1.000000             0.000000                  0.000000
# 25%      7.700000    3.000000             1.500000                  0.500000
# 50%      8.000000    3.000000             2.500000                  1.000000
# 75%      8.300000    4.000000             3.000000                  2.000000
# max      9.000000    4.000000             9.000000                  5.000000
#
#         Room area  Swimming pool       Price
# count  207.000000     208.000000  208.000000
# mean    18.483092       0.250000  129.754808
# std      5.172599       0.434057   29.895025
# min      8.000000       0.000000   63.000000
# 25%     15.000000       0.000000  107.000000
# 50%     18.000000       0.000000  126.000000
# 75%     21.000000       0.250000  151.250000
# max     44.000000       1.000000  210.000000

# %% [markdown]
# Также посмотрим на медианы

# %%
data.median()
# Out:
# Rating                        8.0
# Stars                         3.0
# Distance to the sea           2.5
# Distance to the downtown      1.0
# Room area                    18.0
# Swimming pool                 0.0
# Price                       126.0
# dtype: float64

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
for idx, feature in enumerate(data.columns[1:-1]):
    data.plot(feature, 'Price', subplots=True, kind='scatter', ax=axes[int(idx / 3), int(idx % 3)])

# %% [markdown]
# ### 1.2 Проверка наличия пропусков

# %%
def checkNANs(dataframe):
    print("Есть ли пропуски в датафрейме?: ", dataframe.isnull().values.any())

# %%
checkNANs(data)
# Out:
# Есть ли пропуски в датафрейме?:  True

# %% [markdown]
# Найдем пропуски:

# %%
nan_indexes = data.isnull().any(axis=1)
data[nan_indexes]
# Out:
#                                Hotel name  Rating  Stars  Distance to the sea  \
# 6                           Hotel Barbara     6.6    1.0                  0.5
# 58  Holiday Inn Express Barcelona City 22     7.6    NaN                  0.5
#
#     Distance to the downtown  Room area  Swimming pool  Price
# 6                        0.5        NaN              0     73
# 58                       1.5       25.0              0     96

# %% [markdown]
# ### 1.3 Заполнение пропусков

# %%
mean_dict = data.mean() # cacl mean
for key in mean_dict.keys(): # round values
    mean_dict[key] = int(mean_dict[key])

# %% [markdown]
# Округленные средние значения

# %%
mean_dict
# Out:
# Rating                        7.0
# Stars                         3.0
# Distance to the sea           2.0
# Distance to the downtown      1.0
# Room area                    18.0
# Swimming pool                 0.0
# Price                       129.0
# dtype: float64

# %% [markdown]
# Заполняем средними

# %%
data = data.fillna(mean_dict)

# %% [markdown]
# Проверим заполнение пропусков средним значением:

# %%
data[nan_indexes]
# Out:
#                                Hotel name  Rating  Stars  Distance to the sea  \
# 6                           Hotel Barbara     6.6    1.0                  0.5
# 58  Holiday Inn Express Barcelona City 22     7.6    3.0                  0.5
#
#     Distance to the downtown  Room area  Swimming pool  Price
# 6                        0.5       18.0              0     73
# 58                       1.5       25.0              0     96

# %%
checkNANs(data)
# Out:
# Есть ли пропуски в датафрейме?:  False

# %% [markdown]
# ## 2. Проверка данных

# %% [markdown]
# ### 2.1 Построение корреляционной матрицы

# %%
data.corr()
# Out:
#                             Rating     Stars  Distance to the sea  \
# Rating                    1.000000  0.186994            -0.021557
# Stars                     0.186994  1.000000             0.163200
# Distance to the sea      -0.021557  0.163200             1.000000
# Distance to the downtown -0.128974  0.177517             0.333458
# Room area                 0.191710  0.467148             0.073053
# Swimming pool             0.202255  0.298196             0.054242
# Price                     0.405103  0.593109             0.004539
#
#                           Distance to the downtown  Room area  Swimming pool  \
# Rating                                   -0.128974   0.191710       0.202255
# Stars                                     0.177517   0.467148       0.298196
# Distance to the sea                       0.333458   0.073053       0.054242
# Distance to the downtown                  1.000000   0.147002       0.158823
# Room area                                 0.147002   1.000000       0.265290
# Swimming pool                             0.158823   0.265290       1.000000
# Price                                    -0.109614   0.362466       0.253810
#
#                              Price
# Rating                    0.405103
# Stars                     0.593109
# Distance to the sea       0.004539
# Distance to the downtown -0.109614
# Room area                 0.362466
# Swimming pool             0.253810
# Price                     1.000000

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %% [markdown]
# ### 2.2 Удаление малоинформативных признаков

# %% [markdown]
# Как видно из корреляционной матрицы, зависимость между ценой и расстоянием до моря/центра города очень слабая (меньше 20%). <br>Поэтому, удалим эти признаки.

# %%
data = data.drop(['Distance to the sea'], axis = 1)

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## 3. Предобработка данных

# %%
X_data = data.ix[:,1:].copy()
# X_data = sm.add_constant(X_data)

# %%
# тут будет масштабирование
# или не будет

# %% [markdown]
# ## 4. Обучение модели

# %% [markdown]
# ### 4.1 Обучение МНК

# %%
X_data=X_data.rename(columns = {'Distance to the downtown':'Downtown', 'Room area':'Room', 'Swimming pool': 'Pool'})

# %%
results = smf.ols(formula='np.log(Price) ~ Rating + Stars + Downtown + np.log(Room) - 1', data=X_data).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(Price)   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 2.143e+04
# Date:                Sun, 14 May 2017   Prob (F-statistic):          2.07e-266
# Time:                        19:23:02   Log-Likelihood:                 5.1458
# No. Observations:                 208   AIC:                            -2.292
# Df Residuals:                     204   BIC:                             11.06
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Rating           0.4330      0.021     21.046      0.000         0.392     0.474
# Stars            0.1199      0.023      5.271      0.000         0.075     0.165
# Downtown        -0.0184      0.015     -1.265      0.207        -0.047     0.010
# np.log(Room)     0.3495      0.064      5.434      0.000         0.223     0.476
# ==============================================================================
# Omnibus:                       12.793   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.359
# Skew:                           0.573   Prob(JB):                      0.00126
# Kurtosis:                       3.476   Cond. No.                         37.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results.params
# Out:
# Rating          0.433037
# Stars           0.119867
# Downtown       -0.018435
# np.log(Room)    0.349457
# dtype: float64

# %% [markdown]
# Наиболее простым методом устранения гетероскедастичности остатков модели регрессии является взвешивание параметров модели регрессии. В этом случае отдельным наблюдениям независимой переменой, характеризующимся максимальным среднеквадратическим отклонением случайной ошибки, придаётся больший вес, а остальным наблюдениям с минимальным среднеквадратическим отклонением случайной ошибки придаётся меньший вес. После данной процедуры свойство эффективности оценок неизвестных коэффициентов модели регрессии сохраняется.

# %%
X_data.head()
# Out:
#    Rating  Stars  Downtown  Room  Pool  Price
# 0     7.7    2.0       5.0  16.0     0     63
# 1     7.9    1.0       2.0  15.0     0     83
# 2     7.8    4.0       3.0  21.0     1     91
# 3     7.9    2.0       1.0  10.0     0     87
# 4     8.4    2.0       1.0  19.0     0    102

# %%
p = 0.433037 * 7.7 + 0.119867 * 2 - 0.018435 * 5 + 0.349457 * np.log(16)
print(p)
print(np.log(63))
print(np.log(63) - p)
# Out:
# 4.45084443711
# 4.14313472639
# -0.307709710716

# %% [markdown]
# ### 4.2 Оценка качества

# %% [markdown]
# #### 4.2.1 Тестирование гетероскедастичности

# %% [markdown]
# Нулевая гипотеза: дисперсия остатков не зависит от переменных
# Альтернативная гипотеза: дисперсия остатков зависит от переменных

# %%
hb = smsdia.het_breushpagan(results.resid.values, results.model.exog)

print('LM: ', hb[0])
print('LM_pvalue: ', hb[1])
print('fvalue: ', hb[2])
print('f_value: ', hb[3])
# Out:
# LM:  54.3894917177
# LM_pvalue:  9.26712452715e-12
# fvalue:  18.05777553
# f_value:  1.03397787235e-12

# %% [markdown]
# Т.к. LM > LM_pvalue,присутствует гетероскедастичность

# %% [markdown]
# Корректируем гетероскедастичность (делим на weights - стандартные отклонения)

# %%
def fgls(model):
    return sm.WLS(model.endog, model.exog,
                  1 / np.exp(sm.OLS(np.log(model.fit().resid ** 2), model.exog).fit().predict()))

# %%
wls_model = fgls(results.model).fit()

# %%
hb_wls = smsdia.het_breushpagan(wls_model.resid, wls_model.model.exog)
print('LM: ', hb_wls[0])
print('LM_pvalue: ', hb_wls[1])
print('fvalue: ', hb_wls[2])
print('f_value: ', hb_wls[3])
# Out:
# LM:  49.4634721644
# LM_pvalue:  1.03933122808e-10
# fvalue:  15.9120242813
# f_value:  2.36101900296e-11
