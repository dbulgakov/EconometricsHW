# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from statsmodels.regression.linear_model import WLS
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.outliers_influence import reset_ramsey
import statsmodels.stats.diagnostic as smsdia
from sklearn.metrics import mean_squared_error
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
from statsmodels.graphics.regressionplots import plot_leverage_resid2
# %matplotlib inline

# %% [markdown]
# ## 1. Загрузка данных

# %%
data = pd.read_csv('data/hotel_data.csv', sep=';')

# %%
data.head()
# Out:
#                       Hotel name  Rating  Stars  Distance to the sea  \
# 0                  Bonanova Park     7.7    2.0                  7.0
# 1  Travelodge Barcelona Poblenou     7.9    1.0                  0.5
# 2   Senator Barcelona Spa Hotel      7.8    4.0                  5.0
# 3                  Hotel Medicis     7.9    2.0                  2.0
# 4                     Paral-lel      8.4    2.0                  0.5
#
#    Distance to the downtown  Room area  Swimming pool  Price
# 0                       5.0       16.0              0     63
# 1                       2.0       15.0              0     83
# 2                       3.0       21.0              1     91
# 3                       1.0       10.0              0     87
# 4                       1.0       19.0              0    102

# %% [markdown]
# ### 1.1 Описание данных

# %%
data.describe()
# Out:
#            Rating       Stars  Distance to the sea  Distance to the downtown  \
# count  208.000000  207.000000           208.000000                208.000000
# mean     7.980288    3.260870             2.585096                  1.258173
# std      0.491125    0.841615             1.656875                  1.168520
# min      6.400000    1.000000             0.000000                  0.000000
# 25%      7.700000    3.000000             1.500000                  0.500000
# 50%      8.000000    3.000000             2.500000                  1.000000
# 75%      8.300000    4.000000             3.000000                  2.000000
# max      9.000000    4.000000             9.000000                  5.000000
#
#         Room area  Swimming pool       Price
# count  207.000000     208.000000  208.000000
# mean    18.483092       0.250000  129.754808
# std      5.172599       0.434057   29.895025
# min      8.000000       0.000000   63.000000
# 25%     15.000000       0.000000  107.000000
# 50%     18.000000       0.000000  126.000000
# 75%     21.000000       0.250000  151.250000
# max     44.000000       1.000000  210.000000

# %% [markdown]
# Также посмотрим на медианы

# %%
data.median()
# Out:
# Rating                        8.0
# Stars                         3.0
# Distance to the sea           2.5
# Distance to the downtown      1.0
# Room area                    18.0
# Swimming pool                 0.0
# Price                       126.0
# dtype: float64

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
for idx, feature in enumerate(data.columns[1:-1]):
    data.plot(feature, 'Price', subplots=True, kind='scatter', ax=axes[int(idx / 3), int(idx % 3)])

# %% [markdown]
# ### 1.2 Проверка наличия пропусков

# %%
def checkNANs(dataframe):
    print("Есть ли пропуски в датафрейме?: ", dataframe.isnull().values.any())

# %%
checkNANs(data)
# Out:
# Есть ли пропуски в датафрейме?:  True

# %% [markdown]
# Найдем пропуски:

# %%
nan_indexes = data.isnull().any(axis=1)
data[nan_indexes]
# Out:
#                                Hotel name  Rating  Stars  Distance to the sea  \
# 6                           Hotel Barbara     6.6    1.0                  0.5
# 58  Holiday Inn Express Barcelona City 22     7.6    NaN                  0.5
#
#     Distance to the downtown  Room area  Swimming pool  Price
# 6                        0.5        NaN              0     73
# 58                       1.5       25.0              0     96

# %% [markdown]
# ### 1.3 Заполнение пропусков

# %%
mean_dict = data.mean() # cacl mean
for key in mean_dict.keys(): # round values
    mean_dict[key] = int(mean_dict[key])

# %% [markdown]
# Округленные средние значения

# %%
mean_dict
# Out:
# Rating                        7.0
# Stars                         3.0
# Distance to the sea           2.0
# Distance to the downtown      1.0
# Room area                    18.0
# Swimming pool                 0.0
# Price                       129.0
# dtype: float64

# %% [markdown]
# Заполняем средними

# %%
data = data.fillna(mean_dict)

# %% [markdown]
# Проверим заполнение пропусков средним значением:

# %%
data[nan_indexes]
# Out:
#                                Hotel name  Rating  Stars  Distance to the sea  \
# 6                           Hotel Barbara     6.6    1.0                  0.5
# 58  Holiday Inn Express Barcelona City 22     7.6    3.0                  0.5
#
#     Distance to the downtown  Room area  Swimming pool  Price
# 6                        0.5       18.0              0     73
# 58                       1.5       25.0              0     96

# %%
checkNANs(data)
# Out:
# Есть ли пропуски в датафрейме?:  False

# %% [markdown]
# ## 2. Проверка данных

# %% [markdown]
# ### 2.1 Построение корреляционной матрицы

# %%
data.corr()
# Out:
#                             Rating     Stars  Distance to the sea  \
# Rating                    1.000000  0.186994            -0.021557
# Stars                     0.186994  1.000000             0.163200
# Distance to the sea      -0.021557  0.163200             1.000000
# Distance to the downtown -0.128974  0.177517             0.333458
# Room area                 0.191710  0.467148             0.073053
# Swimming pool             0.202255  0.298196             0.054242
# Price                     0.405103  0.593109             0.004539
#
#                           Distance to the downtown  Room area  Swimming pool  \
# Rating                                   -0.128974   0.191710       0.202255
# Stars                                     0.177517   0.467148       0.298196
# Distance to the sea                       0.333458   0.073053       0.054242
# Distance to the downtown                  1.000000   0.147002       0.158823
# Room area                                 0.147002   1.000000       0.265290
# Swimming pool                             0.158823   0.265290       1.000000
# Price                                    -0.109614   0.362466       0.253810
#
#                              Price
# Rating                    0.405103
# Stars                     0.593109
# Distance to the sea       0.004539
# Distance to the downtown -0.109614
# Room area                 0.362466
# Swimming pool             0.253810
# Price                     1.000000

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %% [markdown]
# ### 2.2 Удаление малоинформативных признаков

# %% [markdown]
# Как видно из корреляционной матрицы, зависимость между ценой и расстоянием до моря/центра города очень слабая (меньше 20%). <br>Поэтому, удалим эти признаки.

# %%
data = data.drop(['Distance to the sea'], axis = 1)

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## 3. Обучение модели

# %%
X_data = data.ix[:,1:].copy()

# %% [markdown]
# ### 3.1 Обучение МНК

# %%
X_data=X_data.rename(columns = {'Distance to the downtown':'Downtown', 'Room area':'Room', 'Swimming pool': 'Pool'})

# %%
results = smf.ols(formula='np.log(Price) ~ Rating + C(Stars) + np.log(Downtown + 1) + np.log(Room) + C(Pool)', data=X_data).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(Price)   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     34.10
# Date:                Mon, 15 May 2017   Prob (F-statistic):           5.39e-31
# Time:                        18:26:28   Log-Likelihood:                 89.255
# No. Observations:                 208   AIC:                            -162.5
# Df Residuals:                     200   BIC:                            -135.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept                3.3800      0.215     15.757      0.000         2.957     3.803
# C(Stars)[T.2.0]          0.0990      0.061      1.624      0.106        -0.021     0.219
# C(Stars)[T.3.0]          0.2870      0.056      5.166      0.000         0.177     0.397
# C(Stars)[T.4.0]          0.4437      0.057      7.743      0.000         0.331     0.557
# C(Pool)[T.1]             0.0184      0.028      0.660      0.510        -0.036     0.073
# Rating                   0.1271      0.024      5.238      0.000         0.079     0.175
# np.log(Downtown + 1)    -0.1021      0.024     -4.334      0.000        -0.149    -0.056
# np.log(Room)             0.0642      0.048      1.340      0.182        -0.030     0.159
# ==============================================================================
# Omnibus:                        1.567   Durbin-Watson:                   1.199
# Prob(Omnibus):                  0.457   Jarque-Bera (JB):                1.647
# Skew:                           0.198   Prob(JB):                        0.439
# Kurtosis:                       2.819   Cond. No.                         168.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 4.2 Оценка качества

# %%
def testModel(results, name, y_true, y_pred, resid):
    print('Params for ' + name + ':')
    print(results.params)
    print('\n')
    
    print('MSE ' + name + ':', mean_squared_error(y_true, y_pred))
    print('\n')
    
    print('Heteroscedasticity test:')
    hb = smsdia.het_breushpagan(resid, results.model.exog)
    print('LM: ', hb[0])
    print('LM_pvalue: ', hb[1])
    print('fvalue: ', hb[2])
    print('f_value: ', hb[3])
    print('\n')
    
    name = ['F statistic', 'p-value']
    test = sms.het_goldfeldquandt(results.resid, results.model.exog)
    print(lzip(name, test))
    
    print('\n')
    print('Jarque-Bera test:')
    name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
    test = sms.jarque_bera(resid)
    print(lzip(name, test))
    
    print('\n')
    print('Multicollinearity: condition number')
    print(np.linalg.cond(results.model.exog))
    
    print('\n')
    print('Ramsey test:')
    print(reset_ramsey(results))
    print('\n')
    
    try:
        fig, ax = plt.subplots(figsize=(8,6))
        fig = plot_leverage_resid2(results, ax = ax)
        plt.show()
    except Exception:
        print('Чет не рисуется:c\n')
        # ignored
        
        
    X_plot = np.linspace(0,1,100)
    plt.plot(results.fittedvalues)
    plt.plot(np.log(X_data['Price']))
    plt.show()
    
    
    X_plot = np.linspace(0,1,208)
    plt.figure(figsize=(20,10))
    plt.scatter(X_plot, results.resid)
    plt.show()

# %%
testModel(results, 'OLS', np.log(X_data['Price'].values), results.fittedvalues, results.resid.values)
# Out:
# Params for OLS:
# Intercept               3.380001
# C(Stars)[T.2.0]         0.099040
# C(Stars)[T.3.0]         0.287047
# C(Stars)[T.4.0]         0.443693
# C(Pool)[T.1]            0.018356
# Rating                  0.127124
# np.log(Downtown + 1)   -0.102079
# np.log(Room)            0.064210
# dtype: float64
#
#
# MSE OLS: 0.024820292178
#
#
# Heteroscedasticity test:
# LM:  6.13518443767
# LM_pvalue:  0.524056361673
# fvalue:  0.868358279501
# f_value:  0.532487913023
#
#
# [('F statistic', 1.2557125155257891), ('p-value', 0.13319450720821366)]
#
#
# Jarque-Bera test:
# [('Jarque-Bera', 1.6467700741925355), ('Chi^2 two-tail prob.', 0.43894329751013916), ('Skew', 0.19829907170284747), ('Kurtosis', 2.819108197298064)]
#
#
# Multicollinearity: condition number
# 167.537044913
#
#
# Ramsey test:
# <F test: F=array([[ 0.88376485]]), p=0.4746376945352724, df_denom=196, df_num=4>

# %% [markdown]
# Нулевая гипотеза: дисперсия остатков не зависит от переменных
# Альтернативная гипотеза: дисперсия остатков зависит от переменных

# %% [markdown]
# Т.к. LM > LM_pvalue,присутствует гетероскедастичность

# %% [markdown]
# Корректируем гетероскедастичность (делим на weights - стандартные отклонения)

# %%
def fgls(model):
    return sm.WLS(model.endog, model.exog,
                  weights=1./np.exp(sm.OLS(np.log(model.fit().resid ** 2), model.exog).fit().predict()))

# %%
wls_results = fgls(results.model).fit()

# %%
wls_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.584
# Model:                            WLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                     56.60
# Date:                Mon, 15 May 2017   Prob (F-statistic):           1.34e-36
# Time:                        17:46:01   Log-Likelihood:                 89.954
# No. Observations:                 208   AIC:                            -167.9
# Df Residuals:                     202   BIC:                            -147.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          2.2393      0.329      6.805      0.000         1.590     2.888
# x1             0.5757      0.120      4.799      0.000         0.339     0.812
# x2             0.5031      0.045     11.134      0.000         0.414     0.592
# x3            -0.1060      0.019     -5.610      0.000        -0.143    -0.069
# x4             0.0402      0.021      1.891      0.060        -0.002     0.082
# x5             0.0167      0.031      0.547      0.585        -0.044     0.077
# ==============================================================================
# Omnibus:                        1.946   Durbin-Watson:                   1.222
# Prob(Omnibus):                  0.378   Jarque-Bera (JB):                1.985
# Skew:                           0.229   Prob(JB):                        0.371
# Kurtosis:                       2.862   Cond. No.                         178.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
testModel(wls_results, 'WLS', np.log(X_data['Price'].values), wls_results.fittedvalues, wls_results.resid)
# Out:
# Params for WLS:
# [ 2.23925652  0.57569707  0.50305472 -0.10597128  0.04015207  0.01671969]
#
#
# MSE WLS: 0.0249780325747
#
#
# Heteroscedasticity test:
# LM:  6.74731344224
# LM_pvalue:  0.240121348451
# fvalue:  1.3544736606
# f_value:  0.243075975572
#
#
# [('F statistic', 1.2663623329668412), ('p-value', 0.12210048364273897)]
#
#
# Jarque-Bera test:
# [('Jarque-Bera', 3.2294175768017537), ('Chi^2 two-tail prob.', 0.19894859814520974), ('Skew', 0.30245565475077213), ('Kurtosis', 2.9181012048152484)]
#
#
# Multicollinearity: condition number
# 198.975621717
#
#
# Ramsey test:
# <F test: F=array([[ 0.83234]]), p=0.5060398437935107, df_denom=198, df_num=4>
#
#
# Чет не рисуется:c
